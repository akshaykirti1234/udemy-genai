# %%
# Basic Syntax Rules in Python
# Case Sensitivity

# %%
# Single line comment

# %%
'''
Multi
Line
comment
'''
# Out:
# '\nMulti\nLine\ncomment\n'

# %%
# Python is case sensitive

name = "Akshay"
Name = "kirti"

print(name)
print(Name)
# Out:
# Akshay
# kirti

# %%
# Indentation
# python uses indentation to define blocks of code. Consistent use of spaces(commonly 4) or a tab is required.

age = 32
if age > 30 :
    print(age)

print(age)
# Out:
# 32
# 32

# %%
# Line continuation

total = 1+2+3+3+4+5+\
4+5+6

print(total)
# Out:
# 33

# %%
# Multiple statements on a single line
x=5; y= 10; z = x+y

print(z)
# Out:
# 15

# %%
# Semantic in python
age = 32  # age is integer
name = "Akshay" # nams is a string

# %%
type(name)
# Out:
# str

# %%
type(age)
# Out:
# int

# %%
# Type Inference
variable = 10
print(type(variable))
variable = "Akshay"
print(type(variable))
# Out:
# <class 'int'>
# <class 'str'>

# %%
# Code examaple of indentation

if True:
    print("Correct indentation")
    if False:
        print("This will not print")
    print("This will print")
print("Outside of if block")
# Out:
# Correct indentation
# This will print
# Outside of if block
