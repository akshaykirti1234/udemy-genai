# %% [markdown]
# #  Data Types

# %% [markdown]
# ### Integers Examples

# %%
age = 26

type(age)
# Out:
# int

# %% [markdown]
# ### Floating point

# %%
height = 5.9

print(height)
print(type(height))
# Out:
# 5.9
# <class 'float'>

# %% [markdown]
# ### String

# %%
name = "Akshay"

print(name)
print(type(name))
# Out:
# Akshay
# <class 'str'>

# %% [markdown]
# ### boolean

# %%
type(True)
# Out:
# bool

# %%
isTrue = True
type(isTrue)
# Out:
# bool

# %%
bool()
# Out:
# False

# %%
a = 10
b = 10

type(a==b)
# Out:
# bool

# %% [markdown]
# ## Commom Error

# %%
# result = "Hello"+5 --> TypeError: can only concatenate str (not "int") to str

# %%
result = "Hello" + str(5)

print(result)
# Out:
# Hello5
